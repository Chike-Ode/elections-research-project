# %%
# Data taken from https://www.elections.ca/content.aspx?section=res&dir=rep/off/42gedata&document=byed&lang=e

# %%
import pandas as pd
from glob import glob
import os
import numpy as np

# %%
directory=os.getcwd().replace('notebooks','data\\raw\\elections\\2015\\')
provinces=next(os.walk(directory))[1]
df_list=[]
for province in provinces:
    province_directory=f'{directory}{province}'
    files=glob(f'{province_directory}\*.csv')
    for file in files:
        df = pd.read_csv(file,index_col=None,header=0)
        df['Province']=province
        df_list.append(df)
election_df=pd.concat(df_list,axis=0,ignore_index=True)
election_df.head(100)
# Out:
#     Electoral District Number/Numéro de circonscription  \
# 0                                               48001
# 1                                               48001
# 2                                               48001
# 3                                               48001
# 4                                               48001
# ..                                                ...
# 95                                              48001
# 96                                              48001
# 97                                              48001
# 98                                              48001
# 99                                              48001
#
#    Electoral District Name_English/Nom de circonscription_Anglais  \
# 0                                      Banff--Airdrie
# 1                                      Banff--Airdrie
# 2                                      Banff--Airdrie
# 3                                      Banff--Airdrie
# 4                                      Banff--Airdrie
# ..                                                ...
# 95                                     Banff--Airdrie
# 96                                     Banff--Airdrie
# 97                                     Banff--Airdrie
# 98                                     Banff--Airdrie
# 99                                     Banff--Airdrie
#
#    Electoral District Name_French/Nom de circonscription_Français  \
# 0                                      Banff--Airdrie
# 1                                      Banff--Airdrie
# 2                                      Banff--Airdrie
# 3                                      Banff--Airdrie
# 4                                      Banff--Airdrie
# ..                                                ...
# 95                                     Banff--Airdrie
# 96                                     Banff--Airdrie
# 97                                     Banff--Airdrie
# 98                                     Banff--Airdrie
# 99                                     Banff--Airdrie
#
#    Polling Station Number/Numéro du bureau de scrutin  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                  2A
# ..                                                ...
# 95                                                21B
# 96                                                 22
# 97                                                 22
# 98                                                 22
# 99                                                 22
#
#    Polling Station Name/Nom du bureau de scrutin  \
# 0                                    Lake Louise
# 1                                    Lake Louise
# 2                                    Lake Louise
# 3                                    Lake Louise
# 4                                          Banff
# ..                                           ...
# 95                                      Cochrane
# 96                                      Cochrane
# 97                                      Cochrane
# 98                                      Cochrane
# 99                                      Cochrane
#
#    Void Poll Indicator/Indicateur de bureau supprimé  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
# ..                                               ...
# 95                                                 N
# 96                                                 N
# 97                                                 N
# 98                                                 N
# 99                                                 N
#
#    No Poll Held Indicator/Indicateur de bureau sans scrutin  \
# 0                                                   N
# 1                                                   N
# 2                                                   N
# 3                                                   N
# 4                                                   N
# ..                                                ...
# 95                                                  N
# 96                                                  N
# 97                                                  N
# 98                                                  N
# 99                                                  N
#
#    Merge With/Fusionné avec  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 95                      NaN
# 96                      NaN
# 97                      NaN
# 98                      NaN
# 99                      NaN
#
#     Rejected Ballots for Polling Station/Bulletins rejetés du bureau  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                   2
# ..                                                ...
# 95                                                  2
# 96                                                  0
# 97                                                  0
# 98                                                  0
# 99                                                  0
#
#     Electors for Polling Station/Électeurs du bureau  \
# 0                                                653
# 1                                                653
# 2                                                653
# 3                                                653
# 4                                                346
# ..                                               ...
# 95                                               377
# 96                                               414
# 97                                               414
# 98                                               414
# 99                                               414
#
#    Candidate’s Family Name/Nom de famille du candidat  \
# 0                                       Boissonneault
# 1                                           MacDonald
# 2                                            Raynolds
# 3                                            Richards
# 4                                       Boissonneault
# ..                                                ...
# 95                                           Richards
# 96                                      Boissonneault
# 97                                          MacDonald
# 98                                           Raynolds
# 99                                           Richards
#
#    Candidate’s Middle Name/Second prénom du candidat  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 95                                               NaN
# 96                                               NaN
# 97                                               NaN
# 98                                               NaN
# 99                                               NaN
#
#    Candidate’s First Name/Prénom du candidat  \
# 0                                     Joanne
# 1                                       Mike
# 2                                      Marlo
# 3                                      Blake
# 4                                     Joanne
# ..                                       ...
# 95                                     Blake
# 96                                    Joanne
# 97                                      Mike
# 98                                     Marlo
# 99                                     Blake
#
#    Political Affiliation Name_English/Appartenance politique_Anglais  \
# 0                            NDP-New Democratic Party
# 1                                         Green Party
# 2                                             Liberal
# 3                                        Conservative
# 4                            NDP-New Democratic Party
# ..                                                ...
# 95                                       Conservative
# 96                           NDP-New Democratic Party
# 97                                        Green Party
# 98                                            Liberal
# 99                                       Conservative
#
#    Political Affiliation Name_French/Appartenance politique_Français  \
# 0                      NPD-Nouveau Parti démocratique
# 1                                          Parti Vert
# 2                                             Libéral
# 3                                        Conservateur
# 4                      NPD-Nouveau Parti démocratique
# ..                                                ...
# 95                                       Conservateur
# 96                     NPD-Nouveau Parti démocratique
# 97                                         Parti Vert
# 98                                            Libéral
# 99                                       Conservateur
#
#    Incumbent Indicator/Indicateur_Candidat sortant  \
# 0                                                N
# 1                                                N
# 2                                                N
# 3                                                Y
# 4                                                N
# ..                                             ...
# 95                                               Y
# 96                                               N
# 97                                               N
# 98                                               N
# 99                                               Y
#
#    Elected Candidate Indicator/Indicateur du candidat élu  \
# 0                                                   N
# 1                                                   N
# 2                                                   N
# 3                                                   Y
# 4                                                   N
# ..                                                ...
# 95                                                  Y
# 96                                                  N
# 97                                                  N
# 98                                                  N
# 99                                                  Y
#
#     Candidate Poll Votes Count/Votes du candidat pour le bureau Province
# 0                                                  74            Alberta
# 1                                                  33            Alberta
# 2                                                 181            Alberta
# 3                                                  61            Alberta
# 4                                                  14            Alberta
# ..                                                ...                ...
# 95                                                162            Alberta
# 96                                                  7            Alberta
# 97                                                  7            Alberta
# 98                                                 84            Alberta
# 99                                                123            Alberta
#
# [100 rows x 19 columns]

# %%
column_names=[]
for column in election_df.columns:
    column_name=column.split('/')[0].replace(' ','_')
    column_names.append(column_name)
election_df.columns=column_names
election_df.head()
# Out:
#    Electoral_District_Number Electoral_District_Name_English  \
# 0                      48001                  Banff--Airdrie
# 1                      48001                  Banff--Airdrie
# 2                      48001                  Banff--Airdrie
# 3                      48001                  Banff--Airdrie
# 4                      48001                  Banff--Airdrie
#
#   Electoral_District_Name_French Polling_Station_Number Polling_Station_Name  \
# 0                 Banff--Airdrie                      1          Lake Louise
# 1                 Banff--Airdrie                      1          Lake Louise
# 2                 Banff--Airdrie                      1          Lake Louise
# 3                 Banff--Airdrie                      1          Lake Louise
# 4                 Banff--Airdrie                     2A                Banff
#
#   Void_Poll_Indicator No_Poll_Held_Indicator Merge_With  \
# 0                   N                      N        NaN
# 1                   N                      N        NaN
# 2                   N                      N        NaN
# 3                   N                      N        NaN
# 4                   N                      N        NaN
#
#    Rejected_Ballots_for_Polling_Station  Electors_for_Polling_Station  \
# 0                                     1                           653
# 1                                     1                           653
# 2                                     1                           653
# 3                                     1                           653
# 4                                     2                           346
#
#   Candidate’s_Family_Name Candidate’s_Middle_Name Candidate’s_First_Name  \
# 0           Boissonneault                     NaN                 Joanne
# 1               MacDonald                     NaN                   Mike
# 2                Raynolds                     NaN                  Marlo
# 3                Richards                     NaN                  Blake
# 4           Boissonneault                     NaN                 Joanne
#
#   Political_Affiliation_Name_English Political_Affiliation_Name_French  \
# 0           NDP-New Democratic Party    NPD-Nouveau Parti démocratique
# 1                        Green Party                        Parti Vert
# 2                            Liberal                           Libéral
# 3                       Conservative                      Conservateur
# 4           NDP-New Democratic Party    NPD-Nouveau Parti démocratique
#
#   Incumbent_Indicator Elected_Candidate_Indicator  Candidate_Poll_Votes_Count  \
# 0                   N                           N                          74
# 1                   N                           N                          33
# 2                   N                           N                         181
# 3                   Y                           Y                          61
# 4                   N                           N                          14
#
#   Province
# 0  Alberta
# 1  Alberta
# 2  Alberta
# 3  Alberta
# 4  Alberta

# %%
election_df.Void_Poll_Indicator.value_counts()
# Out:
# N    399004
# Y       992
# Name: Void_Poll_Indicator, dtype: int64

# %%
election_df.Political_Affiliation_Name_English.value_counts()
# Out:
# Liberal                                                    75075
# Conservative                                               75075
# NDP-New Democratic Party                                   75075
# Green Party                                                74752
# Bloc Québécois                                             18650
# Independent                                                16171
# Libertarian                                                16077
# Marxist-Leninist                                           15691
# Christian Heritage Party                                    6645
# Rhinoceros                                                  6248
# Communist                                                   5682
# Forces et Démocratie - Allier les forces de nos régions     4102
# Animal Alliance/Environment Voters                          1878
# Radical Marijuana                                           1831
# PC Party                                                    1730
# No Affiliation                                              1353
# Pirate                                                      1108
# Democratic Advancement                                       808
# CAP                                                          683
# PACT                                                         274
# ATN                                                          257
# The Bridge                                                   236
# Seniors Party                                                231
# United Party                                                 213
# Canada Party                                                 151
# Name: Political_Affiliation_Name_English, dtype: int64

# %%
election_df['Political_Party']=np.select(
    [
        election_df.Political_Affiliation_Name_English == 'Liberal', 
        election_df.Political_Affiliation_Name_English == 'Conservative',
        election_df.Political_Affiliation_Name_English == 'NDP-New Democratic Party',
        election_df.Political_Affiliation_Name_English == 'Green Party',
        election_df.Political_Affiliation_Name_English == 'Bloc Québécois'
    ], 
                        
    [
        'Liberal', 
        'Conservative',
        'NDP-New Democratic Party',
        'Green Party',
        'Bloc Québécois'
    ], 
default='Other')
election_df['Political_Party']=election_df.Political_Party.str.replace(' ','-')

# %%
election_df.head()
# Out:
#    Electoral_District_Number Electoral_District_Name_English  \
# 0                      48001                  Banff--Airdrie
# 1                      48001                  Banff--Airdrie
# 2                      48001                  Banff--Airdrie
# 3                      48001                  Banff--Airdrie
# 4                      48001                  Banff--Airdrie
#
#   Electoral_District_Name_French Polling_Station_Number Polling_Station_Name  \
# 0                 Banff--Airdrie                      1          Lake Louise
# 1                 Banff--Airdrie                      1          Lake Louise
# 2                 Banff--Airdrie                      1          Lake Louise
# 3                 Banff--Airdrie                      1          Lake Louise
# 4                 Banff--Airdrie                     2A                Banff
#
#   Void_Poll_Indicator No_Poll_Held_Indicator Merge_With  \
# 0                   N                      N        NaN
# 1                   N                      N        NaN
# 2                   N                      N        NaN
# 3                   N                      N        NaN
# 4                   N                      N        NaN
#
#    Rejected_Ballots_for_Polling_Station  Electors_for_Polling_Station  \
# 0                                     1                           653
# 1                                     1                           653
# 2                                     1                           653
# 3                                     1                           653
# 4                                     2                           346
#
#   Candidate’s_Family_Name Candidate’s_Middle_Name Candidate’s_First_Name  \
# 0           Boissonneault                     NaN                 Joanne
# 1               MacDonald                     NaN                   Mike
# 2                Raynolds                     NaN                  Marlo
# 3                Richards                     NaN                  Blake
# 4           Boissonneault                     NaN                 Joanne
#
#   Political_Affiliation_Name_English Political_Affiliation_Name_French  \
# 0           NDP-New Democratic Party    NPD-Nouveau Parti démocratique
# 1                        Green Party                        Parti Vert
# 2                            Liberal                           Libéral
# 3                       Conservative                      Conservateur
# 4           NDP-New Democratic Party    NPD-Nouveau Parti démocratique
#
#   Incumbent_Indicator Elected_Candidate_Indicator  Candidate_Poll_Votes_Count  \
# 0                   N                           N                          74
# 1                   N                           N                          33
# 2                   N                           N                         181
# 3                   Y                           Y                          61
# 4                   N                           N                          14
#
#   Province           Political_Party
# 0  Alberta  NDP-New-Democratic-Party
# 1  Alberta               Green-Party
# 2  Alberta                   Liberal
# 3  Alberta              Conservative
# 4  Alberta  NDP-New-Democratic-Party

# %%
polling_df=pd.DataFrame(election_df.groupby(['Electoral_District_Number','Province','Polling_Station_Number']).agg({'Electors_for_Polling_Station':'max'})).reset_index()
polling_df
# Out:
#        Electoral_District_Number                   Province  \
# 0                          10001  Newfoundland-and-Labrador
# 1                          10001  Newfoundland-and-Labrador
# 2                          10001  Newfoundland-and-Labrador
# 3                          10001  Newfoundland-and-Labrador
# 4                          10001  Newfoundland-and-Labrador
# ...                          ...                        ...
# 75070                      62001                    Nunavut
# 75071                      62001                    Nunavut
# 75072                      62001                    Nunavut
# 75073                      62001                    Nunavut
# 75074                      62001                    Nunavut
#
#       Polling_Station_Number  Electors_for_Polling_Station
# 0                          1                           133
# 1                         10                           365
# 2                        100                           360
# 3                        101                           462
# 4                        102                           289
# ...                      ...                           ...
# 75070                     8B                           421
# 75071                     9A                           455
# 75072                     9B                           411
# 75073                  S/R 1                           190
# 75074                  S/R 2                             0
#
# [75075 rows x 4 columns]

# %%
district_df=pd.DataFrame(polling_df.groupby(['Electoral_District_Number','Province']).agg(Number_of_Polling_Stations=('Polling_Station_Number','nunique'),Number_of_Electors=('Electors_for_Polling_Station','sum'))).reset_index()
district_df
# Out:
#      Electoral_District_Number                   Province  \
# 0                        10001  Newfoundland-and-Labrador
# 1                        10002  Newfoundland-and-Labrador
# 2                        10003  Newfoundland-and-Labrador
# 3                        10004  Newfoundland-and-Labrador
# 4                        10005  Newfoundland-and-Labrador
# ..                         ...                        ...
# 333                      59041           British-Columbia
# 334                      59042           British-Columbia
# 335                      60001                      Yukon
# 336                      61001      Northwest-Territories
# 337                      62001                    Nunavut
#
#      Number_of_Polling_Stations  Number_of_Electors
# 0                           231               68487
# 1                           285               62462
# 2                           239               64226
# 3                            86               20045
# 4                           264               71918
# ..                          ...                 ...
# 333                         267               94627
# 334                         247               90554
# 335                          87               26879
# 336                          93               30110
# 337                          61               20252
#
# [338 rows x 4 columns]

# %%
votes_df=pd.DataFrame(election_df.groupby(['Electoral_District_Number','Province','Political_Party'])['Candidate_Poll_Votes_Count'].sum()).reset_index()
votes_df
# Out:
#       Electoral_District_Number                   Province  \
# 0                         10001  Newfoundland-and-Labrador
# 1                         10001  Newfoundland-and-Labrador
# 2                         10001  Newfoundland-and-Labrador
# 3                         10001  Newfoundland-and-Labrador
# 4                         10001  Newfoundland-and-Labrador
# ...                         ...                        ...
# 1637                      61001      Northwest-Territories
# 1638                      62001                    Nunavut
# 1639                      62001                    Nunavut
# 1640                      62001                    Nunavut
# 1641                      62001                    Nunavut
#
#                Political_Party  Candidate_Poll_Votes_Count
# 0                 Conservative                        4670
# 1                  Green-Party                         228
# 2                      Liberal                       23528
# 3     NDP-New-Democratic-Party                        6075
# 4                        Other                        7585
# ...                        ...                         ...
# 1637  NDP-New-Democratic-Party                        5783
# 1638              Conservative                        2956
# 1639               Green-Party                         182
# 1640                   Liberal                        5619
# 1641  NDP-New-Democratic-Party                        3171
#
# [1642 rows x 4 columns]

# %%
votes_df['Vote_Rank']='Position_'+votes_df.groupby(['Electoral_District_Number'],sort=False)["Candidate_Poll_Votes_Count"].rank(method='dense',ascending=False,axis=0).astype(int).astype(str)
votes_df
# Out:
#       Electoral_District_Number                   Province  \
# 0                         10001  Newfoundland-and-Labrador
# 1                         10001  Newfoundland-and-Labrador
# 2                         10001  Newfoundland-and-Labrador
# 3                         10001  Newfoundland-and-Labrador
# 4                         10001  Newfoundland-and-Labrador
# ...                         ...                        ...
# 1637                      61001      Northwest-Territories
# 1638                      62001                    Nunavut
# 1639                      62001                    Nunavut
# 1640                      62001                    Nunavut
# 1641                      62001                    Nunavut
#
#                Political_Party  Candidate_Poll_Votes_Count   Vote_Rank
# 0                 Conservative                        4670  Position_4
# 1                  Green-Party                         228  Position_5
# 2                      Liberal                       23528  Position_1
# 3     NDP-New-Democratic-Party                        6075  Position_3
# 4                        Other                        7585  Position_2
# ...                        ...                         ...         ...
# 1637  NDP-New-Democratic-Party                        5783  Position_2
# 1638              Conservative                        2956  Position_3
# 1639               Green-Party                         182  Position_4
# 1640                   Liberal                        5619  Position_1
# 1641  NDP-New-Democratic-Party                        3171  Position_2
#
# [1642 rows x 5 columns]

# %%
ranking_df=pd.pivot(votes_df,columns='Vote_Rank',index=['Electoral_District_Number','Province'],values='Political_Party').reset_index()
ranking_df
# Out:
# Vote_Rank  Electoral_District_Number                   Province  \
# 0                              10001  Newfoundland-and-Labrador
# 1                              10002  Newfoundland-and-Labrador
# 2                              10003  Newfoundland-and-Labrador
# 3                              10004  Newfoundland-and-Labrador
# 4                              10005  Newfoundland-and-Labrador
# ..                               ...                        ...
# 333                            59041           British-Columbia
# 334                            59042           British-Columbia
# 335                            60001                      Yukon
# 336                            61001      Northwest-Territories
# 337                            62001                    Nunavut
#
# Vote_Rank                Position_1                Position_2  \
# 0                           Liberal                     Other
# 1                           Liberal              Conservative
# 2                           Liberal              Conservative
# 3                           Liberal  NDP-New-Democratic-Party
# 4                           Liberal              Conservative
# ..                              ...                       ...
# 333        NDP-New-Democratic-Party               Green-Party
# 334                         Liberal              Conservative
# 335                         Liberal              Conservative
# 336                         Liberal  NDP-New-Democratic-Party
# 337                         Liberal  NDP-New-Democratic-Party
#
# Vote_Rank                Position_3    Position_4   Position_5 Position_6
# 0          NDP-New-Democratic-Party  Conservative  Green-Party        NaN
# 1          NDP-New-Democratic-Party   Green-Party          NaN        NaN
# 2          NDP-New-Democratic-Party   Green-Party          NaN        NaN
# 3                      Conservative           NaN          NaN        NaN
# 4          NDP-New-Democratic-Party   Green-Party          NaN        NaN
# ..                              ...           ...          ...        ...
# 333                         Liberal  Conservative        Other        NaN
# 334        NDP-New-Democratic-Party   Green-Party        Other        NaN
# 335        NDP-New-Democratic-Party   Green-Party          NaN        NaN
# 336                    Conservative   Green-Party          NaN        NaN
# 337                    Conservative   Green-Party          NaN        NaN
#
# [338 rows x 8 columns]

# %%
ranking_df['Position_1'].value_counts()
# Out:
# Liberal                     184
# Conservative                 99
# NDP-New-Democratic-Party     44
# Bloc-Québécois               10
# Green-Party                   1
# Name: Position_1, dtype: int64

# %%
party_votes_df=pd.pivot(votes_df,values='Candidate_Poll_Votes_Count',index=['Electoral_District_Number','Province'],columns='Political_Party').reset_index()
party_votes_df=party_votes_df.fillna(0)
party_votes_df['Vote_Total']=party_votes_df['Bloc-Québécois']+party_votes_df['Conservative']+party_votes_df['Green-Party']+party_votes_df['Liberal']+party_votes_df['NDP-New-Democratic-Party']+party_votes_df['Other']
party_votes_df
# Out:
# Political_Party  Electoral_District_Number                   Province  \
# 0                                    10001  Newfoundland-and-Labrador
# 1                                    10002  Newfoundland-and-Labrador
# 2                                    10003  Newfoundland-and-Labrador
# 3                                    10004  Newfoundland-and-Labrador
# 4                                    10005  Newfoundland-and-Labrador
# ..                                     ...                        ...
# 333                                  59041           British-Columbia
# 334                                  59042           British-Columbia
# 335                                  60001                      Yukon
# 336                                  61001      Northwest-Territories
# 337                                  62001                    Nunavut
#
# Political_Party  Bloc-Québécois  Conservative  Green-Party  Liberal  \
# 0                           0.0        4670.0        228.0  23528.0
# 1                           0.0        3534.0        297.0  28704.0
# 2                           0.0        6479.0        271.0  26523.0
# 3                           0.0        1716.0          0.0   8878.0
# 4                           0.0        5085.0       1111.0  30889.0
# ..                          ...           ...          ...      ...
# 333                         0.0        8480.0      23666.0   8489.0
# 334                         0.0       17411.0       5907.0  36300.0
# 335                         0.0        4928.0        533.0  10887.0
# 336                         0.0        3481.0        537.0   9172.0
# 337                         0.0        2956.0        182.0   5619.0
#
# Political_Party  NDP-New-Democratic-Party   Other  Vote_Total
# 0                                  6075.0  7585.0     42086.0
# 1                                  2557.0     0.0     35092.0
# 2                                  2175.0     0.0     35448.0
# 3                                  1779.0     0.0     12373.0
# 4                                  4739.0     0.0     41824.0
# ..                                    ...     ...         ...
# 333                               30397.0   863.0     71895.0
# 334                                6554.0   286.0     66458.0
# 335                                3943.0     0.0     20291.0
# 336                                5783.0     0.0     18973.0
# 337                                3171.0     0.0     11928.0
#
# [338 rows x 9 columns]

# %%
final_df=(party_votes_df
         .merge(ranking_df,how='inner',on=['Electoral_District_Number','Province'])
         .merge(district_df,how='inner',on=['Electoral_District_Number','Province']))
final_df['Percent_Liberal']=final_df['Liberal']/final_df['Vote_Total']
final_df['Percent_Bloc-Québécois']=final_df['Bloc-Québécois']/final_df['Vote_Total']
final_df['Percent_Conservative']=final_df['Conservative']/final_df['Vote_Total']
final_df['Percent_Green-Party']=final_df['Green-Party']/final_df['Vote_Total']
final_df['Percent_NDP-New-Democratic-Party']=final_df['NDP-New-Democratic-Party']/final_df['Vote_Total']
final_df['Percent_Other']=final_df['Other']/final_df['Vote_Total']

final_df['Voter_Participation']=final_df['Vote_Total']/final_df['Number_of_Electors']
final_df=final_df.set_index(['Electoral_District_Number','Province'])
final_df=final_df.add_prefix('2015_')
final_df=final_df.reset_index()
final_df.head()
# Out:
#    Electoral_District_Number                   Province  2015_Bloc-Québécois  \
# 0                      10001  Newfoundland-and-Labrador                  0.0
# 1                      10002  Newfoundland-and-Labrador                  0.0
# 2                      10003  Newfoundland-and-Labrador                  0.0
# 3                      10004  Newfoundland-and-Labrador                  0.0
# 4                      10005  Newfoundland-and-Labrador                  0.0
#
#    2015_Conservative  2015_Green-Party  2015_Liberal  \
# 0             4670.0             228.0       23528.0
# 1             3534.0             297.0       28704.0
# 2             6479.0             271.0       26523.0
# 3             1716.0               0.0        8878.0
# 4             5085.0            1111.0       30889.0
#
#    2015_NDP-New-Democratic-Party  2015_Other  2015_Vote_Total 2015_Position_1  \
# 0                         6075.0      7585.0          42086.0         Liberal
# 1                         2557.0         0.0          35092.0         Liberal
# 2                         2175.0         0.0          35448.0         Liberal
# 3                         1779.0         0.0          12373.0         Liberal
# 4                         4739.0         0.0          41824.0         Liberal
#
#    ... 2015_Position_6 2015_Number_of_Polling_Stations  \
# 0  ...             NaN                             231
# 1  ...             NaN                             285
# 2  ...             NaN                             239
# 3  ...             NaN                              86
# 4  ...             NaN                             264
#
#   2015_Number_of_Electors 2015_Percent_Liberal 2015_Percent_Bloc-Québécois  \
# 0                   68487             0.559046                         0.0
# 1                   62462             0.817964                         0.0
# 2                   64226             0.748223                         0.0
# 3                   20045             0.717530                         0.0
# 4                   71918             0.738547                         0.0
#
#    2015_Percent_Conservative  2015_Percent_Green-Party  \
# 0                   0.110963                  0.005417
# 1                   0.100707                  0.008463
# 2                   0.182775                  0.007645
# 3                   0.138689                  0.000000
# 4                   0.121581                  0.026564
#
#    2015_Percent_NDP-New-Democratic-Party  2015_Percent_Other  \
# 0                               0.144347            0.180226
# 1                               0.072866            0.000000
# 2                               0.061357            0.000000
# 3                               0.143781            0.000000
# 4                               0.113308            0.000000
#
#    2015_Voter_Participation
# 0                  0.614511
# 1                  0.561814
# 2                  0.551926
# 3                  0.617261
# 4                  0.581551
#
# [5 rows x 24 columns]

# %%
export_directory=directory.replace('\\raw\\elections\\2015\\','\\output\\elections\\')
final_df.to_csv(f'{export_directory}2015_election_results.csv',index=False)
