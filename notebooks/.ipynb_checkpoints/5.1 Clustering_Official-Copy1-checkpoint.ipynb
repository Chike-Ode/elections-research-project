# %%
import sklearn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns
# from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.cluster import KMeans
import pandas as pd
import pickle
import joblib
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
import os
directory=os.getcwd().replace('notebooks','data\\output\\census_elections\\')
model_directory=os.getcwd().replace('notebooks','models\\')
filename="census_election_totals_and_percent_data.csv"
full_name=f"{directory}{filename}"
full_df=pd.read_csv(full_name).set_index(['District_Name_x','Electoral_District_Number'])
del full_df['employment_employed']
del full_df['employment_unemployed']
del full_df['employment_not_in_the_labour_force']
del full_df['District_Name_y']
# del full_df['District_Name_x']
del full_df['employment_employment_rate']
del full_df['employment_participation_rate']
del full_df['ALT_GEO_CODE_y']
del full_df['ALT_GEO_CODE_x']
y = full_df['employment_unemployment_rate']
X = full_df.drop('employment_unemployment_rate',1).fillna(0)
categorical_fields=X.select_dtypes(include='object').columns
X=pd.get_dummies(data=X,columns=categorical_fields,drop_first=True)
output_directory=directory.replace('\\output\\census_elections\\','\\output\\model_output\\')
# CV_feat_importances_df=pd.read_csv(f'{output_directory}CV_percent_feat_importances_df.csv')
CV_feat_importances_df=pd.read_csv(f'{output_directory}CV_feat_importances_df.csv')

important_columns=list(CV_feat_importances_df.nlargest(50,'score')['fields'])
X=X[important_columns]
uncorrelated_columns=list(calc_vif(X).nsmallest(columns='VIF',n=15)['variables'])
X=X[uncorrelated_columns]
calc_vif(X).sort_values('VIF').reset_index()
X = sm.add_constant(X) # adding a constant

model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42).fit(X)
X['cluster']=kmeans.predict(X)
X=X.reset_index().set_index(['cluster','District_Name_x','Electoral_District_Number'])
print(print_model)
# del full_df['ALT_GEO_CODE']
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     employment_unemployment_rate   R-squared:                       0.449
# Model:                                      OLS   Adj. R-squared:                  0.423
# Method:                           Least Squares   F-statistic:                     17.48
# Date:                          Fri, 24 Sep 2021   Prob (F-statistic):           1.77e-33
# Time:                                  20:31:48   Log-Likelihood:                -734.17
# No. Observations:                           338   AIC:                             1500.
# Df Residuals:                               322   BIC:                             1562.
# Df Model:                                    15
# Covariance Type:                      nonrobust
# ==================================================================================================================================================
#                                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                             14.2460      0.775     18.388      0.000      12.722      15.770
# 2015-2019_EOE_Percent_Change_Liberal_Votes                                         0.9052      0.733      1.234      0.218      -0.538       2.348
# 2019_NDP-New-Democratic-Party_Votes                                            -8.708e-05   2.68e-05     -3.249      0.001      -0.000   -3.43e-05
# ethnic_southeast_asian                                                            -0.0002      0.000     -1.181      0.239      -0.001       0.000
# ethnic_latin_american                                                              0.0003      0.000      1.515      0.131    -8.3e-05       0.001
# ethnic_percent_black                                                               2.9458      5.506      0.535      0.593      -7.886      13.778
# median_value_of_dwellings_($)                                                  -3.132e-06   8.44e-07     -3.712      0.000   -4.79e-06   -1.47e-06
# industry_71_arts_entertainment_and_recreation                                     -0.0007      0.000     -1.867      0.063      -0.001     3.7e-05
# industry_percent_finance_and_insurance                                           -33.1760      9.461     -3.507      0.001     -51.788     -14.564
# ethnic_multiple_visible_minorities                                                 0.0012      0.000      3.376      0.001       0.001       0.002
# education_subject_visual_and_performing_arts_and_communications_technologies       0.0004      0.000      1.661      0.098   -6.72e-05       0.001
# industry_41_wholesale_trade                                                       -0.0013      0.000     -7.016      0.000      -0.002      -0.001
# education_level_percent_university_certificate_or_diploma_below_bachelor_level    -2.9228      9.093     -0.321      0.748     -20.813      14.967
# marital_status_living_common_law                                                  -0.0001   2.79e-05     -4.297      0.000      -0.000    -6.5e-05
# industry_percent_mining_quarrying_and_oil_and_gas_extraction                      42.6202     15.229      2.799      0.005      12.659      72.582
# industry_21_mining_quarrying_and_oil_and_gas_extraction                           -0.0004      0.000     -1.517      0.130      -0.001       0.000
# ==============================================================================
# Omnibus:                      140.782   Durbin-Watson:                   1.632
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              848.414
# Skew:                           1.627   Prob(JB):                    5.88e-185
# Kurtosis:                      10.046   Cond. No.                     5.92e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.92e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.matshow(full_df.corr())
plt.show()

# %%
from IPython.display import display
import os
directory=os.getcwd().replace('notebooks','data\\output\\census_elections\\')
model_directory=os.getcwd().replace('notebooks','models\\')
filename="census_election_totals_and_percent_data.csv"
full_name=f"{directory}{filename}"
output_directory=directory.replace('\\output\\census_elections\\','\\output\\model_output\\')
# CV_feat_importances_df=pd.read_csv(f'{output_directory}CV_percent_feat_importances_df.csv')
CV_feat_importances_df=pd.read_csv(f'{output_directory}CV_feat_importances_df.csv')

important_columns=list(CV_feat_importances_df.nlargest(150,'score')['fields'])
full_df=pd.read_csv(full_name).set_index(['District_Name_x','Electoral_District_Number'])
del full_df['employment_employed']
del full_df['employment_unemployed']
del full_df['employment_not_in_the_labour_force']
del full_df['District_Name_y']
# del full_df['District_Name_x']
del full_df['employment_employment_rate']
del full_df['employment_participation_rate']
del full_df['ALT_GEO_CODE_y']
del full_df['ALT_GEO_CODE_x']
y = full_df['employment_unemployment_rate']

full_df2=full_df
y2 = full_df2['employment_unemployment_rate']
categorical_fields=full_df2.select_dtypes(include='object').columns
full_df2=pd.get_dummies(data=full_df2,columns=categorical_fields,drop_first=True)
corr_matrix = full_df2.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.70)]

# Drop features 
full_df2=full_df2.drop(to_drop, axis=1)
try:
    X2 = full_df2.drop('employment_unemployment_rate',1).fillna(0)
except KeyError:
    X2=full_df2
X2 = X2.loc[:, X2.columns.isin(important_columns)]
X2=X2.drop(['2015_Other_Votes','2015-2019_EOE_Percent_Change_Green-Party_Votes','2015_NDP-New-Democratic-Party_Votes','2015_Conservative_Votes','2015-2019_Absolute_Change_Conservative'],1)
print(X2.shape)
uncorrelated_columns=list(calc_vif(X2).nsmallest(columns='VIF',n=25)['variables'])
X2=X2[uncorrelated_columns]
display(calc_vif(X2).sort_values('VIF').reset_index().head(50))
X2 = sm.add_constant(X2) # adding a constant

model = sm.OLS(y2, X2).fit()
predictions = model.predict(X2) 

print_model = model.summary()
print(print_model)
# Out:
# C:\Users\Chike\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel_launcher.py:31: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (338, 31)
#     index                                          variables        VIF
# 0       0                    education_subject_percent_other   1.732086
# 1       1                home_ownership_percent_band_housing   2.071410
# 2       2  industry_percent_mining_quarrying_and_oil_and_...   2.768463
# 3       3                            ethnic_percent_japanese   3.136516
# 4       4          population_percentage_change_2011_to_2016   3.699230
# 5       6                               ethnic_percent_black   4.675912
# 6       5              home_type_percent_semi-detached_house   4.700115
# 7       7        _of_tenant_households_in_subsidized_housing   8.467432
# 8       8  education_level_percent_degree_in_medicine_den...  13.538236
# 9      11  employee_departure_time_percent_between_5_a.m....  18.276161
# 10      9           immigration_arrival_percent_2011_to_2016  20.174681
# 11     10                   industry_percent_wholesale_trade  23.549416
# 12     12  education_level_percent_university_certificate...  23.825372
# 13     13            immigration_arrival_percent_before_1981  25.369831
# 14     18                   marital_status_percent_separated  34.795345
# 15     15   employment_type_percent_0_management_occupations  38.305371
# 16     14           immigration_arrival_percent_1981_to_1990  40.663879
# 17     16  industry_percent_administrative_and_support_wa...  42.307995
# 18     17                         age_percent_25_to_29_years  43.959407
# 19     23       employment_type_percent_3_health_occupations  55.955896
# 20     19  employment_type_percent_4_occupations_in_educa...  71.512500
# 21     20  industry_percent_other_services_(except_public...  74.007711
# 22     22                education_subject_percent_education  77.845885
# 23     21                           age_percent_0_to_4_years  78.092667
# 24     24                         age_percent_20_to_24_years  79.508830
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     employment_unemployment_rate   R-squared:                       0.628
# Model:                                      OLS   Adj. R-squared:                  0.598
# Method:                           Least Squares   F-statistic:                     21.04
# Date:                          Fri, 24 Sep 2021   Prob (F-statistic):           1.07e-52
# Time:                                  22:38:39   Log-Likelihood:                -667.85
# No. Observations:                           338   AIC:                             1388.
# Df Residuals:                               312   BIC:                             1487.
# Df Model:                                    25
# Covariance Type:                      nonrobust
# =======================================================================================================================================================================
#                                                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                  27.9658      2.469     11.327      0.000      23.108      32.824
# education_subject_percent_other                                                                     -3152.1704    529.822     -5.949      0.000   -4194.647   -2109.694
# home_ownership_percent_band_housing                                                                    16.1532      4.993      3.235      0.001       6.329      25.978
# industry_percent_mining_quarrying_and_oil_and_gas_extraction                                           23.6973      5.053      4.690      0.000      13.755      33.639
# ethnic_percent_japanese                                                                               -81.2435     39.271     -2.069      0.039    -158.513      -3.974
# population_percentage_change_2011_to_2016                                                               0.0328      0.024      1.366      0.173      -0.014       0.080
# home_type_percent_semi-detached_house                                                                  -7.9806      3.706     -2.154      0.032     -15.272      -0.690
# ethnic_percent_black                                                                                   12.5515      4.150      3.025      0.003       4.387      20.716
# _of_tenant_households_in_subsidized_housing                                                             0.0832      0.019      4.331      0.000       0.045       0.121
# education_level_percent_degree_in_medicine_dentistry_veterinary_medicine_or_optometry                  96.5368     27.218      3.547      0.000      42.982     150.091
# immigration_arrival_percent_2011_to_2016                                                                6.4739      2.265      2.859      0.005       2.018      10.930
# industry_percent_wholesale_trade                                                                      -31.2863     13.050     -2.397      0.017     -56.963      -5.610
# employee_departure_time_percent_between_5_a.m._and_5:59_a.m.                                          -17.2944      6.041     -2.863      0.004     -29.181      -5.408
# education_level_percent_university_certificate_or_diploma_below_bachelor_level                         -4.2411      9.889     -0.429      0.668     -23.699      15.216
# immigration_arrival_percent_before_1981                                                                 2.7503      1.475      1.865      0.063      -0.152       5.652
# immigration_arrival_percent_1981_to_1990                                                                2.2645      5.936      0.381      0.703      -9.415      13.944
# employment_type_percent_0_management_occupations                                                      -62.2904      5.952    -10.466      0.000     -74.001     -50.580
# industry_percent_administrative_and_support_waste_management_and_remediation_services                 -31.9354     14.750     -2.165      0.031     -60.957      -2.914
# age_percent_25_to_29_years                                                                            -30.2847      9.768     -3.100      0.002     -49.505     -11.065
# marital_status_percent_separated                                                                      -14.1096     22.749     -0.620      0.536     -58.871      30.652
# employment_type_percent_4_occupations_in_education_law_and_social_community_and_government_services     8.8053      6.975      1.262      0.208      -4.918      22.528
# industry_percent_other_services_(except_public_administration)                                        -59.2294     20.067     -2.952      0.003     -98.714     -19.745
# age_percent_0_to_4_years                                                                              -39.4627     16.014     -2.464      0.014     -70.972      -7.953
# education_subject_percent_education                                                                   -54.5161     21.948     -2.484      0.014     -97.700     -11.332
# employment_type_percent_3_health_occupations                                                          -49.5368     11.917     -4.157      0.000     -72.986     -26.088
# age_percent_20_to_24_years                                                                            -34.4773     13.892     -2.482      0.014     -61.811      -7.143
# ==============================================================================
# Omnibus:                       77.518   Durbin-Watson:                   1.653
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              259.868
# Skew:                           0.987   Prob(JB):                     3.72e-57
# Kurtosis:                       6.816   Cond. No.                     8.54e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.54e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from IPython.display import display
output_directory=directory.replace('\\output\\census_elections\\','\\output\\model_output\\')
# CV_feat_importances_df=pd.read_csv(f'{output_directory}CV_percent_feat_importances_df.csv')
CV_feat_importances_df=pd.read_csv(f'{output_directory}CV_feat_importances_df.csv')

important_columns=list(CV_feat_importances_df.nlargest(150,'score')['fields'])

full_df2=full_df
y3 = full_df2['employment_unemployment_rate']
categorical_fields=full_df2.select_dtypes(include='object').columns
full_df2=pd.get_dummies(data=full_df2,columns=categorical_fields,drop_first=True)
corr_matrix = full_df2.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.75)]

# Drop features 
full_df2=full_df2.drop(to_drop, axis=1)
try:
    X2 = full_df2.drop('employment_unemployment_rate',1).fillna(0)
except KeyError:
    X2=full_df2
X2 = X2.loc[:, X2.columns.isin(important_columns)].filter(regex='percent')
# X2=X2.drop(['2015_Other_Votes','2015-2019_EOE_Percent_Change_Green-Party_Votes','2015_NDP-New-Democratic-Party_Votes','2015_Conservative_Votes','2015-2019_Absolute_Change_Conservative'],1)
print(X2.shape)
#Select top 2 features based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =17)
selector.fit(X2, y2)
X3=X2[X2.columns[selector.get_support()]]
display(calc_vif(X3).sort_values('VIF').reset_index().head(50))
X3 = sm.add_constant(X3) # adding a constant

model = sm.OLS(y2, X3).fit()
predictions = model.predict(X3) 

print_model = model.summary()
display(print_model)
results_as_html = print_model.tables[1].as_html()
results_df=pd.read_html(results_as_html, header=0, index_col=0)[0]
results_df.index.name = 'variable'
results_df=results_df.reset_index()
results_df2=results_df[results_df['P>|t|'] <= 0.05]
columns=list(results_df2['variable'])
columns.remove('const')
columns
# Out:
# C:\Users\Chike\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# (338, 35)
#     index                                          variables         VIF
# 0      13  industry_percent_mining_quarrying_and_oil_and_...    1.802809
# 1       4                              ethnic_percent_korean    2.206822
# 2       5                            ethnic_percent_japanese    2.922627
# 3       3                     ethnic_percent_southeast_asian    3.244935
# 4       2                               ethnic_percent_black    4.419013
# 5      16            immigration_arrival_percent_before_1981   17.318205
# 6      14                   industry_percent_wholesale_trade   17.822959
# 7       9                   marital_status_percent_separated   27.492374
# 8       7                         age_percent_25_to_29_years   31.535472
# 9      11  employee_departure_time_percent_between_6_a.m....   39.188800
# 10      0   employment_type_percent_0_management_occupations   42.870248
# 11     15  industry_percent_administrative_and_support_wa...   55.352787
# 12      6                         age_percent_20_to_24_years   59.374966
# 13     12  employee_departure_time_percent_between_7_a.m....   87.165573
# 14      8                         age_percent_55_to_59_years  165.241279
# 15      1  employment_type_percent_6_sales_and_service_oc...  176.291098
# 16     10  married_lone_parent_percent_total_couple_families  519.798357
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     employment_unemployment_rate   R-squared:                       0.559
# Model:                                      OLS   Adj. R-squared:                  0.536
# Method:                           Least Squares   F-statistic:                     23.91
# Date:                          Fri, 24 Sep 2021   Prob (F-statistic):           4.23e-47
# Time:                                  23:07:23   Log-Likelihood:                -696.28
# No. Observations:                           338   AIC:                             1429.
# Df Residuals:                               320   BIC:                             1497.
# Df Model:                                    17
# Covariance Type:                      nonrobust
# =========================================================================================================================================================
#                                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                    36.5980      4.602      7.953      0.000      27.544      45.652
# employment_type_percent_0_management_occupations                                        -45.4689      6.244     -7.282      0.000     -57.754     -33.184
# employment_type_percent_6_sales_and_service_occupations                                 -11.0169      6.632     -1.661      0.098     -24.064       2.030
# ethnic_percent_black                                                                     11.7533      4.496      2.614      0.009       2.907      20.600
# ethnic_percent_southeast_asian                                                           -3.5925     14.011     -0.256      0.798     -31.157      23.972
# ethnic_percent_korean                                                                    15.6929     14.474      1.084      0.279     -12.784      44.170
# ethnic_percent_japanese                                                                -108.7904     41.355     -2.631      0.009    -190.153     -27.427
# age_percent_20_to_24_years                                                              -30.3085     12.970     -2.337      0.020     -55.825      -4.792
# age_percent_25_to_29_years                                                              -31.1526      8.890     -3.504      0.001     -48.643     -13.662
# age_percent_55_to_59_years                                                               -0.9958     18.620     -0.053      0.957     -37.629      35.638
# marital_status_percent_separated                                                         38.5148     22.826      1.687      0.093      -6.393      83.422
# married_lone_parent_percent_total_couple_families                                       -11.8207      4.696     -2.517      0.012     -21.059      -2.583
# employee_departure_time_percent_between_6_a.m._and_6:59_a.m.                            -31.2860      3.679     -8.503      0.000     -38.524     -24.047
# employee_departure_time_percent_between_7_a.m._and_7:59_a.m.                             -3.2112      3.460     -0.928      0.354     -10.019       3.596
# industry_percent_mining_quarrying_and_oil_and_gas_extraction                             34.6492      4.401      7.873      0.000      25.990      43.308
# industry_percent_wholesale_trade                                                        -30.7787     11.994     -2.566      0.011     -54.375      -7.182
# industry_percent_administrative_and_support_waste_management_and_remediation_services   -28.9180     17.492     -1.653      0.099     -63.333       5.497
# immigration_arrival_percent_before_1981                                                  -0.1750      1.287     -0.136      0.892      -2.708       2.358
# ==============================================================================
# Omnibus:                      112.515   Durbin-Watson:                   1.385
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.098
# Skew:                           1.345   Prob(JB):                    1.04e-111
# Kurtosis:                       8.390   Cond. No.                         558.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# ['employment_type_percent_0_management_occupations',
#  'ethnic_percent_black',
#  'ethnic_percent_japanese',
#  'age_percent_20_to_24_years',
#  'age_percent_25_to_29_years',
#  'married_lone_parent_percent_total_couple_families',
#  'employee_departure_time_percent_between_6_a.m._and_6:59_a.m.',
#  'industry_percent_mining_quarrying_and_oil_and_gas_extraction',
#  'industry_percent_wholesale_trade']

# %%
pd.options.display.max_columns = None

feats=X2[columns].nlargest(45,'ethnic_percent_black')
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42).fit(feats)
feats['cluster']=kmeans.predict(feats)

# %%
from sklearn.cluster import KMeans
wcss = [] 
for i in range(1, 11): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(feats) 
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

# %%
X
# Out:
#                                                                               const  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                      1.000
# Bonavista--Burin--Trinity                          10002                      1.000
# Coast of Bays--Central--Notre Dame                 10003                      1.000
# Labrador                                           10004                      1.000
# Long Range Mountains                               10005                      1.000
# ...                                                                             ...
# Victoria                                           59041                      1.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                      1.000
# Yukon                                              60001                      1.000
# Northwest Territories                              61001                      1.000
# Nunavut                                            62001                      1.000
#
#                                                                               education_subject_percent_other  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                0.000
# Bonavista--Burin--Trinity                          10002                                                0.000
# Coast of Bays--Central--Notre Dame                 10003                                                0.000
# Labrador                                           10004                                                0.000
# Long Range Mountains                               10005                                                0.000
# ...                                                                                                       ...
# Victoria                                           59041                                                0.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                0.000
# Yukon                                              60001                                                0.000
# Northwest Territories                              61001                                                0.000
# Nunavut                                            62001                                                0.000
#
#                                                                               2015-2019_EOE_Percent_Change_Percent_Riding_Votes_NDP-New-Democratic-Party  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                                  0.197
# Bonavista--Burin--Trinity                          10002                                                                  0.644
# Coast of Bays--Central--Notre Dame                 10003                                                                  1.014
# Labrador                                           10004                                                                  0.703
# Long Range Mountains                               10005                                                                  0.748
# ...                                                                                                                         ...
# Victoria                                           59041                                                                 -0.214
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                                  0.409
# Yukon                                              60001                                                                  0.130
# Northwest Territories                              61001                                                                 -0.267
# Nunavut                                            62001                                                                  0.536
#
#                                                                               2015-2019_Absolute_Change_Percent_Riding_Votes_Green-Party  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                                  0.048
# Bonavista--Burin--Trinity                          10002                                                                  0.020
# Coast of Bays--Central--Notre Dame                 10003                                                                  0.032
# Labrador                                           10004                                                                  0.020
# Long Range Mountains                               10005                                                                  0.008
# ...                                                                                                                         ...
# Victoria                                           59041                                                                 -0.030
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                                  0.135
# Yukon                                              60001                                                                  0.078
# Northwest Territories                              61001                                                                  0.078
# Nunavut                                            62001                                                                  0.007
#
#                                                                               home_type_percent_semi-detached_house  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                      0.014
# Bonavista--Burin--Trinity                          10002                                                      0.012
# Coast of Bays--Central--Notre Dame                 10003                                                      0.037
# Labrador                                           10004                                                      0.120
# Long Range Mountains                               10005                                                      0.036
# ...                                                                                                             ...
# Victoria                                           59041                                                      0.023
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                      0.038
# Yukon                                              60001                                                      0.077
# Northwest Territories                              61001                                                      0.065
# Nunavut                                            62001                                                      0.090
#
#                                                                               2015-2019_EOE_Percent_Change_Liberal_Votes  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                          -0.187
# Bonavista--Burin--Trinity                          10002                                                          -0.488
# Coast of Bays--Central--Notre Dame                 10003                                                          -0.377
# Labrador                                           10004                                                          -0.454
# Long Range Mountains                               10005                                                          -0.411
# ...                                                                                                                  ...
# Victoria                                           59041                                                           0.879
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                          -0.375
# Yukon                                              60001                                                          -0.354
# Northwest Territories                              61001                                                          -0.295
# Nunavut                                            62001                                                          -0.481
#
#                                                                               population_density_per_square_kilometre  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                       13.400
# Bonavista--Burin--Trinity                          10002                                                        4.400
# Coast of Bays--Central--Notre Dame                 10003                                                        2.000
# Labrador                                           10004                                                        0.100
# Long Range Mountains                               10005                                                        2.300
# ...                                                                                                               ...
# Victoria                                           59041                                                     2907.900
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                        9.200
# Yukon                                              60001                                                        0.100
# Northwest Territories                              61001                                                        0.000
# Nunavut                                            62001                                                        0.000
#
#                                                                               ethnic_filipino  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                               65.000
# Bonavista--Burin--Trinity                          10002                               70.000
# Coast of Bays--Central--Notre Dame                 10003                               80.000
# Labrador                                           10004                              425.000
# Long Range Mountains                               10005                              155.000
# ...                                                                                       ...
# Victoria                                           59041                             2045.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                             2010.000
# Yukon                                              60001                             1195.000
# Northwest Territories                              61001                             1300.000
# Nunavut                                            62001                              230.000
#
#                                                                               population_percentage_change_2011_to_2016  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                          6.000
# Bonavista--Burin--Trinity                          10002                                                         -3.400
# Coast of Bays--Central--Notre Dame                 10003                                                         -0.500
# Labrador                                           10004                                                          1.800
# Long Range Mountains                               10005                                                         -1.200
# ...                                                                                                                 ...
# Victoria                                           59041                                                          5.600
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                          5.500
# Yukon                                              60001                                                          5.800
# Northwest Territories                              61001                                                          0.800
# Nunavut                                            62001                                                         12.700
#
#                                                                               2019_Percent_Riding_Votes_Green-Party  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                      0.054
# Bonavista--Burin--Trinity                          10002                                                      0.029
# Coast of Bays--Central--Notre Dame                 10003                                                      0.040
# Labrador                                           10004                                                      0.020
# Long Range Mountains                               10005                                                      0.035
# ...                                                                                                             ...
# Victoria                                           59041                                                      0.299
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                      0.224
# Yukon                                              60001                                                      0.105
# Northwest Territories                              61001                                                      0.106
# Nunavut                                            62001                                                      0.022
#
#                                                                               ethnic_latin_american  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                     50.000
# Bonavista--Burin--Trinity                          10002                                     10.000
# Coast of Bays--Central--Notre Dame                 10003                                     25.000
# Labrador                                           10004                                     25.000
# Long Range Mountains                               10005                                     10.000
# ...                                                                                             ...
# Victoria                                           59041                                    980.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                    635.000
# Yukon                                              60001                                    135.000
# Northwest Territories                              61001                                    135.000
# Nunavut                                            62001                                     40.000
#
#                                                                               _of_tenant_households_in_subsidized_housing  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                           12.900
# Bonavista--Burin--Trinity                          10002                                                           20.700
# Coast of Bays--Central--Notre Dame                 10003                                                           23.400
# Labrador                                           10004                                                           26.800
# Long Range Mountains                               10005                                                           24.900
# ...                                                                                                                   ...
# Victoria                                           59041                                                           12.500
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                           11.500
# Yukon                                              60001                                                           25.100
# Northwest Territories                              61001                                                           41.200
# Nunavut                                            62001                                                           83.500
#
#                                                                               immigrant_category_percent_non-permanent_residents  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                                  0.001
# Bonavista--Burin--Trinity                          10002                                                                  0.002
# Coast of Bays--Central--Notre Dame                 10003                                                                  0.001
# Labrador                                           10004                                                                  0.010
# Long Range Mountains                               10005                                                                  0.002
# ...                                                                                                                         ...
# Victoria                                           59041                                                                  0.030
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                                  0.028
# Yukon                                              60001                                                                  0.013
# Northwest Territories                              61001                                                                  0.008
# Nunavut                                            62001                                                                  0.002
#
#                                                                               industry_71_arts_entertainment_and_recreation  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                                            495.000
# Bonavista--Burin--Trinity                          10002                                                            495.000
# Coast of Bays--Central--Notre Dame                 10003                                                            350.000
# Labrador                                           10004                                                            165.000
# Long Range Mountains                               10005                                                            465.000
# ...                                                                                                                     ...
# Victoria                                           59041                                                           1905.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                                           2375.000
# Yukon                                              60001                                                            595.000
# Northwest Territories                              61001                                                            350.000
# Nunavut                                            62001                                                            285.000
#
#                                                                               median_value_of_dwellings_($)  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                         255983.000
# Bonavista--Burin--Trinity                          10002                                         139367.000
# Coast of Bays--Central--Notre Dame                 10003                                         149507.000
# Labrador                                           10004                                         240486.000
# Long Range Mountains                               10005                                         160311.000
# ...                                                                                                     ...
# Victoria                                           59041                                         601878.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                         800447.000
# Yukon                                              60001                                         358721.000
# Northwest Territories                              61001                                         321099.000
# Nunavut                                            62001                                         300924.000
#
#                                                                               industry_31-33_manufacturing  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                          3065.000
# Bonavista--Burin--Trinity                          10002                                          4980.000
# Coast of Bays--Central--Notre Dame                 10003                                          2155.000
# Labrador                                           10004                                           565.000
# Long Range Mountains                               10005                                          2590.000
# ...                                                                                                    ...
# Victoria                                           59041                                          1780.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                          2350.000
# Yukon                                              60001                                           340.000
# Northwest Territories                              61001                                           245.000
# Nunavut                                            62001                                           145.000
#
#                                                                               education_level_earned_doctorate  \
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                                               105.000
# Bonavista--Burin--Trinity                          10002                                                30.000
# Coast of Bays--Central--Notre Dame                 10003                                                40.000
# Labrador                                           10004                                                20.000
# Long Range Mountains                               10005                                               120.000
# ...                                                                                                        ...
# Victoria                                           59041                                              1515.000
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                                               830.000
# Yukon                                              60001                                               110.000
# Northwest Territories                              61001                                                85.000
# Nunavut                                            62001                                                45.000
#
#                                                                               cluster
# District_Name_x                                    Electoral_District_Number
# Avalon                                             10001                            0
# Bonavista--Burin--Trinity                          10002                            0
# Coast of Bays--Central--Notre Dame                 10003                            0
# Labrador                                           10004                            0
# Long Range Mountains                               10005                            0
# ...                                                                               ...
# Victoria                                           59041                            1
# West Vancouver--Sunshine Coast--Sea to Sky Country 59042                            1
# Yukon                                              60001                            2
# Northwest Territories                              61001                            0
# Nunavut                                            62001                            0
#
# [338 rows x 18 columns]

# %%
feats.groupby(['cluster']).mean()
# Out:
#          employment_type_percent_0_management_occupations  \
# cluster
# 0                                                0.099604
# 1                                                0.058450
# 2                                                0.088093
#
#          ethnic_percent_black  ethnic_percent_japanese  \
# cluster
# 0                    0.100576                 0.001265
# 1                    0.233501                 0.001279
# 2                    0.108529                 0.002135
#
#          age_percent_20_to_24_years  age_percent_25_to_29_years  \
# cluster
# 0                          0.069929                    0.066354
# 1                          0.073107                    0.068935
# 2                          0.070978                    0.073194
#
#          married_lone_parent_percent_total_couple_families  \
# cluster
# 0                                                 0.827865
# 1                                                 0.690828
# 2                                                 0.773229
#
#          employee_departure_time_percent_between_6_a.m._and_6:59_a.m.  \
# cluster
# 0                                                 0.197079
# 1                                                 0.199630
# 2                                                 0.161115
#
#          industry_percent_mining_quarrying_and_oil_and_gas_extraction  \
# cluster
# 0                                                 0.005733
# 1                                                 0.000732
# 2                                                 0.001766
#
#          industry_percent_wholesale_trade
# cluster
# 0                                0.047216
# 1                                0.040350
# 2                                0.038951

# %%
feats.cluster.value_counts()
# Out:
# 2    23
# 0    18
# 1     4
# Name: cluster, dtype: int64

# %%
# Out:
#                                            District_Name_x  \
# cluster
# 0                                                   Avalon
# 0                                Bonavista--Burin--Trinity
# 0                       Coast of Bays--Central--Notre Dame
# 0                                                 Labrador
# 0                                     Long Range Mountains
# ...                                                    ...
# 1                                                 Victoria
# 1        West Vancouver--Sunshine Coast--Sea to Sky Cou...
# 2                                                    Yukon
# 0                                    Northwest Territories
# 0                                                  Nunavut
#
#          Electoral_District_Number  const  education_subject_percent_other  \
# cluster
# 0                            10001  1.000                            0.000
# 0                            10002  1.000                            0.000
# 0                            10003  1.000                            0.000
# 0                            10004  1.000                            0.000
# 0                            10005  1.000                            0.000
# ...                            ...    ...                              ...
# 1                            59041  1.000                            0.000
# 1                            59042  1.000                            0.000
# 2                            60001  1.000                            0.000
# 0                            61001  1.000                            0.000
# 0                            62001  1.000                            0.000
#
#          2015-2019_EOE_Percent_Change_Percent_Riding_Votes_NDP-New-Democratic-Party  \
# cluster
# 0                                                    0.197
# 0                                                    0.644
# 0                                                    1.014
# 0                                                    0.703
# 0                                                    0.748
# ...                                                    ...
# 1                                                   -0.214
# 1                                                    0.409
# 2                                                    0.130
# 0                                                   -0.267
# 0                                                    0.536
#
#          2015-2019_Absolute_Change_Percent_Riding_Votes_Green-Party  \
# cluster
# 0                                                    0.048
# 0                                                    0.020
# 0                                                    0.032
# 0                                                    0.020
# 0                                                    0.008
# ...                                                    ...
# 1                                                   -0.030
# 1                                                    0.135
# 2                                                    0.078
# 0                                                    0.078
# 0                                                    0.007
#
#          home_type_percent_semi-detached_house  \
# cluster
# 0                                        0.014
# 0                                        0.012
# 0                                        0.037
# 0                                        0.120
# 0                                        0.036
# ...                                        ...
# 1                                        0.023
# 1                                        0.038
# 2                                        0.077
# 0                                        0.065
# 0                                        0.090
#
#          2015-2019_EOE_Percent_Change_Liberal_Votes  \
# cluster
# 0                                            -0.187
# 0                                            -0.488
# 0                                            -0.377
# 0                                            -0.454
# 0                                            -0.411
# ...                                             ...
# 1                                             0.879
# 1                                            -0.375
# 2                                            -0.354
# 0                                            -0.295
# 0                                            -0.481
#
#          population_density_per_square_kilometre  ethnic_filipino  \
# cluster
# 0                                         13.400           65.000
# 0                                          4.400           70.000
# 0                                          2.000           80.000
# 0                                          0.100          425.000
# 0                                          2.300          155.000
# ...                                          ...              ...
# 1                                       2907.900         2045.000
# 1                                          9.200         2010.000
# 2                                          0.100         1195.000
# 0                                          0.000         1300.000
# 0                                          0.000          230.000
#
#          population_percentage_change_2011_to_2016  \
# cluster
# 0                                            6.000
# 0                                           -3.400
# 0                                           -0.500
# 0                                            1.800
# 0                                           -1.200
# ...                                            ...
# 1                                            5.600
# 1                                            5.500
# 2                                            5.800
# 0                                            0.800
# 0                                           12.700
#
#          2019_Percent_Riding_Votes_Green-Party  ethnic_latin_american  \
# cluster
# 0                                        0.054                 50.000
# 0                                        0.029                 10.000
# 0                                        0.040                 25.000
# 0                                        0.020                 25.000
# 0                                        0.035                 10.000
# ...                                        ...                    ...
# 1                                        0.299                980.000
# 1                                        0.224                635.000
# 2                                        0.105                135.000
# 0                                        0.106                135.000
# 0                                        0.022                 40.000
#
#          _of_tenant_households_in_subsidized_housing  \
# cluster
# 0                                             12.900
# 0                                             20.700
# 0                                             23.400
# 0                                             26.800
# 0                                             24.900
# ...                                              ...
# 1                                             12.500
# 1                                             11.500
# 2                                             25.100
# 0                                             41.200
# 0                                             83.500
#
#          immigrant_category_percent_non-permanent_residents  \
# cluster
# 0                                                    0.001
# 0                                                    0.002
# 0                                                    0.001
# 0                                                    0.010
# 0                                                    0.002
# ...                                                    ...
# 1                                                    0.030
# 1                                                    0.028
# 2                                                    0.013
# 0                                                    0.008
# 0                                                    0.002
#
#          industry_71_arts_entertainment_and_recreation  \
# cluster
# 0                                              495.000
# 0                                              495.000
# 0                                              350.000
# 0                                              165.000
# 0                                              465.000
# ...                                                ...
# 1                                             1905.000
# 1                                             2375.000
# 2                                              595.000
# 0                                              350.000
# 0                                              285.000
#
#          median_value_of_dwellings_($)  industry_31-33_manufacturing  \
# cluster
# 0                           255983.000                      3065.000
# 0                           139367.000                      4980.000
# 0                           149507.000                      2155.000
# 0                           240486.000                       565.000
# 0                           160311.000                      2590.000
# ...                                ...                           ...
# 1                           601878.000                      1780.000
# 1                           800447.000                      2350.000
# 2                           358721.000                       340.000
# 0                           321099.000                       245.000
# 0                           300924.000                       145.000
#
#          education_level_earned_doctorate
# cluster
# 0                                 105.000
# 0                                  30.000
# 0                                  40.000
# 0                                  20.000
# 0                                 120.000
# ...                                   ...
# 1                                1515.000
# 1                                 830.000
# 2                                 110.000
# 0                                  85.000
# 0                                  45.000
#
# [338 rows x 19 columns]

# %%
full_df.columns[full_df.isna().any()].tolist()

# %%
pd.options.display.max_columns = None
full_df

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
model=RandomForestRegressor(random_state=12)
model.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)
y_pred

# %%
mean_squared_error(y_test,y_pred)

# %%
model.feature_importances_

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.index.name='fields'
feat_importances_df=feat_importances.to_frame(name='score').sort_values('score',ascending=False).reset_index()#.rename('index','fields')#,'0':'score'})
feat_importances_df.head(60)# feat_importances.nlargest(20)#.plot(kind='barh')

# %%
model.get_params()

# %%
predict_df=y_test.to_frame()
predict_df['predict_unemployment_rate']=y_pred
predict_df=predict_df.reset_index()

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(20, 110, num = 4)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(random_grid)

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 5, cv = 3, verbose=3, random_state=42, n_jobs = -1)
# Fit the random search model
rf_random.fit(X_train, y_train)

# %%
rf_random.best_params_

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

# %%
base_accuracy = evaluate(model, X_test, y_test)

# %%
best_random = rf_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)

# %%
print('Improvement of {:0.2f}%.'.format( 100 * (random_accuracy - base_accuracy) / base_accuracy))

# %%
mean_squared_error(y_test,y_pred)

# %%
CV_feat_importances = pd.Series(best_random.feature_importances_, index=X.columns)
CV_feat_importances.index.name='fields'
CV_feat_importances_df=feat_importances.to_frame(name='score').sort_values('score',ascending=False).reset_index()#.rename('index','fields')#,'0':'score'})
CV_feat_importances_df.head(60)

# %%
CV_predict_df=y_test.to_frame()
CV_predict_df['predict_unemployment_rate']=y_pred
CV_predict_df=CV_predict_df.reset_index()
CV_predict_df

# %%
output_directory=directory.replace('\\output\\census_elections\\','\\output\\model_output\\')
CV_feat_importances_df.to_csv(f'{output_directory}CV_feat_importances_df.csv')
CV_predict_df.to_csv(f'{output_directory}CV_predict_df.csv')
feat_importances_df.to_csv(f'{output_directory}feat_importances_df.csv')
predict_df.to_csv(f'{output_directory}predict_df.csv')
print(directory)
print(output_directory)

print(model_directory)
model_directory=directory.replace('\\data\\output\\census_elections\\','\\models\\')
joblib.dump(model, f'{model_directory}base_rf_model.pkl', compress=9)
joblib.dump(best_random, f'{model_directory}best_rf_model.pkl', compress=9)
